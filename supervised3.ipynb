# %% [markdown]
# <a href="https://colab.research.google.com/github/anjankumar1432/aaaaannn/blob/main/supervised3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb

# %%
aa=pd.read_csv('/content/matches.cvs.csv')
aa
# Out:
#       id  season       city      date                        team1  \
# 0      1    2017  Hyderabad  5/4/2017          Sunrisers Hyderabad
# 1      2    2017       Pune  6/4/2017               Mumbai Indians
# 2      3    2017     Rajkot  7/4/2017                Gujarat Lions
# 3      4    2017     Indore  8/4/2017       Rising Pune Supergiant
# 4      5    2017  Bangalore  8/4/2017  Royal Challengers Bangalore
# ..   ...     ...        ...       ...                          ...
# 631  632    2016     Raipur  22/05/16             Delhi Daredevils
# 632  633    2016  Bangalore  24/05/16                Gujarat Lions
# 633  634    2016      Delhi  25/05/16          Sunrisers Hyderabad
# 634  635    2016      Delhi  27/05/16                Gujarat Lions
# 635  636    2016  Bangalore  29/05/16          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
aa.drop(["id", "season", "date", "dl_applied", "player_of_match", "umpire1", "umpire2", "umpire3"], axis=1, inplace=True)

# %%
aa
# Out:
#           city                        team1                        team2  \
# 0    Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1         Pune               Mumbai Indians       Rising Pune Supergiant
# 2       Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3       Indore       Rising Pune Supergiant              Kings XI Punjab
# 4    Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# ..         ...                          ...                          ...
# 631     Raipur             Delhi Daredevils  Royal Challengers Bangalore
# 632  Bangalore                Gujarat Lions  Royal Challengers Bangalore
# 633      Delhi          Sunrisers Hyderabad        Kolkata Knight Riders
# 634      Delhi                Gujarat Lions          Sunrisers Hyderabad
# 635  Bangalore          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                      toss_winner toss_decision  result  \
# ...

# %%
aa['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
L=LabelEncoder()

# %%
aa['city']=L.fit_transform(aa['city'])

# %%
aa['team1']=L.fit_transform(aa['team1'])

# %%
aa['team2']=L.fit_transform(aa['team2'])

# %%
aa['toss_winner']=L.fit_transform(aa['toss_winner'])

# %%
aa['toss_decision']=L.fit_transform(aa['toss_decision'])

# %%
aa['result']=L.fit_transform(aa['result'])

# %%
aa['winner']=L.fit_transform(aa['winner'])

# %%
aa['win_by_runs']=L.fit_transform(aa['win_by_runs'])

# %%
aa['toss_decision']=L.fit_transform(aa['toss_decision'])

# %%
aa['venue']=L.fit_transform(aa['venue'])

# %%
aa
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  winner  \
# 0      13     13     12           12              1       1      13
# 1      24      7     10           10              1       1      10
# 2      26      3      6            6              1       1       6
# 3      14     10      4            4              1       1       4
# 4       2     12      2           12              0       1      12
# ..    ...    ...    ...          ...            ...     ...     ...
# 631    25      2     12           12              1       1      12
# 632     2      3     12           12              1       1      12
# 633     9     13      6            6              1       1      13
# 634     9      3     13           13              1       1      13
# 635     2     13     12           13              0       1      13
#
#      win_by_runs  win_by_wickets  venue  t
# 0             35               0     23  1
# 1              0               7     16  1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
y=aa["winner"]
x=aa[["city","team1","team2","toss_winner","toss_decision","result","venue"]]

# %%
y
# Out:
# 0      13
# 1      10
# 2       6
# 3       4
# 4      12
#        ..
# 631    12
# 632    12
# 633    13
# 634    13
# 635    13
# Name: winner, Length: 636, dtype: int64

# %%
x
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  venue
# 0      13     13     12           12              1       1     23
# 1      24      7     10           10              1       1     16
# 2      26      3      6            6              1       1     25
# 3      14     10      4            4              1       1     11
# 4       2     12      2           12              0       1     14
# ..    ...    ...    ...          ...            ...     ...    ...
# 631    25      2     12           12              1       1     27
# 632     2      3     12           12              1       1     14
# 633     9     13      6            6              1       1      8
# 634     9      3     13           13              1       1      8
# 635     2     13     12           13              0       1     14
#
# [636 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
sb.pairplot(aa,hue='winner')

# %%
from sklearn.linear_model import LogisticRegression

# %%
Ir=LogisticRegression()

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
xtest
# Out:
#      city  team1  team2  toss_winner  toss_decision  result  venue
# 583    13     13      6           13              0       1     23
# 505    20      6     12           12              1       1      7
# 205     7      0      9            0              0       1     15
# 607    20      6      4            4              1       1      7
# 228     9      1      2            1              0       1      8
# ..    ...    ...    ...          ...            ...     ...    ...
# 57      2      6      7            7              1       1     14
# 28     24     10      6            6              1       1     16
# 289    14      5      4            4              1       1     11
# 496     8      7      6            6              1       1      0
# 265     9      6      2            2              1       1      8
#
# [159 rows x 7 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
Ir = LogisticRegression(max_iter=200)

# %%
Ir.fit(xtrain, ytrain)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=200)

# %%
ypred = Ir.predict(xtest)

# %%
ypred = Ir.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.3046875

# %%
import pickle

# %%
pickle.dump(Ir,open('match.pkl','wb'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-80eea7b8428a> in <cell line: 0>()
# ----> 1 pickle.dump(Ir,open('match.pkl','wb'))
#
# NameError: name 'Ir' is not defined
